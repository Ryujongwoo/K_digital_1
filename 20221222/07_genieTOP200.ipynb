# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=1 => 1 ~ 50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=2 => 51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg='
for i in range(1, 5):
    # targetSite = url + str(i)
    targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=4

# %%
targetSite = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg=1'
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'}
req = requests.get(targetSite, headers=header)
print(req)
html = req.text
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <Response [200]>
#
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->
# <!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->
# <!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->
# <!--[if IE 9]><html dir="ltr" class="no-js ie9"><![endif]-->
# <!--[if (gte IE 10)|!(IE)]><!--><html class="no-js" dir="ltr"><!--<![endif]-->
# <title>음악, 그리고 설레임 - 지니</title>
# <meta charset="utf-8"/>
# <meta content="d17289f97c7f294985a9b0eb3649a45ac5ceeee2" name="naver-site-verification"/>
# <meta content="-l7MNwwsDcn29Pnu00OagSrpDUPbjqLYoY08rhXLde8" name="google-site-verification"/>
# <meta content="가격은 가볍게, 추천은 확실하게! 최저가로 즐기는 프리미어 사운드! 국내 최초 실시간 TOP 200 차트" name="description"/>
# <meta content="width=1200" name="viewport"/>
# <meta content="" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    req = requests.get(targetSite, headers=header)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    for i in range(len(titles)):
        # print('{:3d}위 {}'.format(i + 1, titles[i].text.strip()))
        # print('{:3d}위 {}'.format(i + 1, titles[i].text.split('\n')[-1].strip()))
        print('{:3d}위 {}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 Ditto
#   2위 사건의 지평선
#   3위 NOT SORRY (Feat. pH-1) (Prod. by Slom)
#   4위 Hype boy
#   5위 ANTIFRAGILE
#   6위 Candy
#   7위 After LIKE
#   8위 사랑은 늘 도망가
#   9위 Attention
#  10위 All I Want for Christmas Is You
#  11위 Nxde
#  12위 우리들의 블루스
#  13위 새삥 (Prod. by ZICO) (Feat. 호미들)
#  14위 마이웨이 (MY WAY) (Prod. by R.Tee)
#  15위 다시 만날 수 있을까
#  16위 이제 나만 믿어요
#  17위 Santa Tell Me
#  18위 London Boy
#  19위 LOVE DIVE
#  20위 Polaroid
#  21위 무지개
#  22위 아버지
#  23위 A bientot
#  24위 손이 참 곱던 그대
#  25위 Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)
#  26위 Monologue
#  27위 Snowman
#  28위 사랑해 진짜
#  29위 Shut Down
#  30위 인생찬가
#  31위 연애편지
#  32위 Pink Venom
#  33위 보금자리
#  34위 미리 메리 크리스마스 (Feat. 천둥 of MBLAQ)
#  35위 눈 (EYE) (Feat. BIG Naughty & 저스디스 (JUSTHIS)) (Prod. by R.Tee)
#  36위 Rush Hour (Feat. j-hope of BTS)
#  37위 TOMBOY
#  38위 그때 그 순간 그대로 (그그그)
#  39위 WHEN I MOVE
#  40위 크리스마스니까
#  41위 Last Christmas
#  42위 Cookie
#  43위 사랑인가 봐
#  44위 That's Hilarious
# ...

# %%
# 아트스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    req = requests.get(targetSite, headers=header)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    '''
    i = 1
    for artist in artists[5:]:
        print('{:3d}위 {}'.format(i, artist.text.strip()))
        i += 1
    '''
    '''
    for i in range(len(artists[5:])):
        print('{:3d}위 {}'.format(i + 1, artists[i + 5].text.strip()))
    '''
    
    for i in range(5, len(artists)):
        # print('{:3d}위 {}'.format(i - 4, artists[i].text.strip()))
        # print('{:3d}위 {}'.format(i - 4, artists[i].text.split('\n')[0]))
        print('{:3d}위 {}'.format(i - 4, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 NewJeans
#   2위 윤하 (YOUNHA)
#   3위 이영지
#   4위 NewJeans
#   5위 LE SSERAFIM (르세라핌)
#   6위 NCT DREAM
#   7위 IVE (아이브)
#   8위 임영웅
#   9위 NewJeans
#  10위 Mariah Carey
#  11위 (여자)아이들
#  12위 임영웅
#  13위 지코 (ZICO)
#  14위 저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현 (Huh) & KHAN & 맥대디 (Mckdaddy) & Los
#  15위 임영웅
#  16위 임영웅
#  17위 Ariana Grande
#  18위 임영웅
#  19위 IVE (아이브)
#  20위 임영웅
#  21위 임영웅
#  22위 임영웅
#  23위 임영웅
#  24위 임영웅
#  25위 정국 & 방탄소년단
#  26위 테이 (Tei)
#  27위 Sia
#  28위 임영웅
#  29위 BLACKPINK
#  30위 임영웅
#  31위 임영웅
#  32위 BLACKPINK
#  33위 임영웅
#  34위 아이유 (IU)
#  35위 던말릭 (DON MALIK)
#  36위 Crush
#  37위 (여자)아이들
#  38위 WSG워너비 (가야G)
#  39위 카라 (KARA)
#  40위 성시경 & 박효신 & 이석훈 & 서인국 & VIXX (빅스)
#  41위 Wham!
#  42위 NewJeans
#  43위 멜로망스 (MeloMance)
#  44위 Charlie Puth
#  45위 주호
#  46위 #안녕
#  47위 BE'O (비오)
#  48위 성시경
#  49위 KHAN
#  50위 경서예지 & 전건호

# %%
# 크롤링한 4페이지 결과를 하나의 리스트에 모은다.
genie = []
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20221222&hh=12&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    req = requests.get(targetSite, headers=header)
    time.sleep(1)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    
    for j in range(50):
        genie.append(
            (artists[j + 5].text.strip().split('\n')[0], titles[j].text.strip().split('\n')[-1])
        )
print(genie)
# Out:
# [('NewJeans', 'Ditto'), ('윤하 (YOUNHA)', '사건의 지평선'), ('이영지', 'NOT SORRY (Feat. pH-1) (Prod. by Slom)'), ('NewJeans', 'Hype boy'), ('LE SSERAFIM (르세라핌)', 'ANTIFRAGILE'), ('NCT DREAM', 'Candy'), ('IVE (아이브)', 'After LIKE'), ('임영웅', '사랑은 늘 도망가'), ('NewJeans', 'Attention'), ('Mariah Carey', 'All I Want for Christmas Is You'), ('(여자)아이들', 'Nxde'), ('임영웅', '우리들의 블루스'), ('지코 (ZICO)', '새삥 (Prod. by ZICO) (Feat. 호미들)'), ('저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현 (Huh) & KHAN & 맥대디 (Mckdaddy) & Los', '마이웨이 (MY WAY) (Prod. by R.Tee)'), ('임영웅', '다시 만날 수 있을까'), ('임영웅', '이제 나만 믿어요'), ('Ariana Grande', 'Santa Tell Me'), ('임영웅', 'London Boy'), ('IVE (아이브)', 'LOVE DIVE'), ('임영웅', 'Polaroid'), ('임영웅', '무지개'), ('임영웅', '아버지'), ('임영웅', 'A bientot'), ('임영웅', '손이 참 곱던 그대'), ('정국 & 방탄소년단', 'Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)'), ('테이 (Tei)', 'Monologue'), ('Sia', 'Snowman'), ('임영웅', '사랑해 진짜'), ('BLACKPINK', 'Shut Down'), ('임영웅', '인생찬가'), ('임영웅', '연
# ...

# %%
print(dt.now())
for i in range(200):
    print('{:3d}위 {} - {}'.format(i + 1, genie[i][0], genie[i][1]))
# Out:
# 2022-12-22 15:14:34.153174
#   1위 NewJeans - Ditto
#   2위 윤하 (YOUNHA) - 사건의 지평선
#   3위 이영지 - NOT SORRY (Feat. pH-1) (Prod. by Slom)
#   4위 NewJeans - Hype boy
#   5위 LE SSERAFIM (르세라핌) - ANTIFRAGILE
#   6위 NCT DREAM - Candy
#   7위 IVE (아이브) - After LIKE
#   8위 임영웅 - 사랑은 늘 도망가
#   9위 NewJeans - Attention
#  10위 Mariah Carey - All I Want for Christmas Is You
#  11위 (여자)아이들 - Nxde
#  12위 임영웅 - 우리들의 블루스
#  13위 지코 (ZICO) - 새삥 (Prod. by ZICO) (Feat. 호미들)
#  14위 저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현 (Huh) & KHAN & 맥대디 (Mckdaddy) & Los - 마이웨이 (MY WAY) (Prod. by R.Tee)
#  15위 임영웅 - 다시 만날 수 있을까
#  16위 임영웅 - 이제 나만 믿어요
#  17위 Ariana Grande - Santa Tell Me
#  18위 임영웅 - London Boy
#  19위 IVE (아이브) - LOVE DIVE
#  20위 임영웅 - Polaroid
#  21위 임영웅 - 무지개
#  22위 임영웅 - 아버지
#  23위 임영웅 - A bientot
#  24위 임영웅 - 손이 참 곱던 그대
#  25위 정국 & 방탄소년단 - Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)
#  26위 테이 (Tei) - Monologue
#  27위 Sia - Snowman
#  28위 임영웅 - 사랑해 진짜
# ...

# %%
with open('./output/genieTOP200.txt', 'w', -1, 'utf-8') as file:
    file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
    for i in range(200):
        file.write('{:3d}위 {} - {}\n'.format(i + 1, genie[i][0], genie[i][1]))
print('genieTOP200.txt 파일로 쓰기 완료')
# Out:
# genieTOP200.txt 파일로 쓰기 완료

# %%
try:
    file = open('./output/genieTOP200.txt', 'r', -1, 'utf-8')
    lines = file.readlines()
    for line in lines:
        print(line.rstrip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2022-12-22 15:14:34
#   1위 NewJeans - Ditto
#   2위 윤하 (YOUNHA) - 사건의 지평선
#   3위 이영지 - NOT SORRY (Feat. pH-1) (Prod. by Slom)
#   4위 NewJeans - Hype boy
#   5위 LE SSERAFIM (르세라핌) - ANTIFRAGILE
#   6위 NCT DREAM - Candy
#   7위 IVE (아이브) - After LIKE
#   8위 임영웅 - 사랑은 늘 도망가
#   9위 NewJeans - Attention
#  10위 Mariah Carey - All I Want for Christmas Is You
#  11위 (여자)아이들 - Nxde
#  12위 임영웅 - 우리들의 블루스
#  13위 지코 (ZICO) - 새삥 (Prod. by ZICO) (Feat. 호미들)
#  14위 저스디스 (JUSTHIS) & R.Tee & 던말릭 (DON MALIK) & 허성현 (Huh) & KHAN & 맥대디 (Mckdaddy) & Los - 마이웨이 (MY WAY) (Prod. by R.Tee)
#  15위 임영웅 - 다시 만날 수 있을까
#  16위 임영웅 - 이제 나만 믿어요
#  17위 Ariana Grande - Santa Tell Me
#  18위 임영웅 - London Boy
#  19위 IVE (아이브) - LOVE DIVE
#  20위 임영웅 - Polaroid
#  21위 임영웅 - 무지개
#  22위 임영웅 - 아버지
#  23위 임영웅 - A bientot
#  24위 임영웅 - 손이 참 곱던 그대
#  25위 정국 & 방탄소년단 - Dreamers (Music from the FIFA World Cup Qatar 2022 Official Soundtrack) (Feat. FIFA Sound)
#  26위 테이 (Tei) - Monologue
#  27위 Sia - Snowman
#  28위 임영웅 - 사랑해 진짜
# ...
