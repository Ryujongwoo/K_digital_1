# %%
import warnings
warnings.filterwarnings(action='ignore')
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# %%
option = Options()
option.add_argument('--window-size=1890,1030')
driver = webdriver.Chrome('./chromedriver.exe', options=option)
driver.implicitly_wait(5)

driver.get('https://comic.naver.com/comment/comment?titleId=790713&no=87')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# 전체 댓글을 연다.
# driver.find_element_by_xpath('//*[@id="cbox_module_wai_u_cbox_sort_option_tab2"]/span[2]').click()
driver.find_element_by_css_selector('#cbox_module_wai_u_cbox_sort_option_tab2 > .u_cbox_sort_label').click()
time.sleep(1)

# 1페이지 댓글을 읽는다.
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
reviews = soup.select('span.u_cbox_contents')
for review in reviews:
    print(review.text)
print('댓글 1페이지', '=' * 80, '\n')

count = 2
# 댓글 페이지 그룹 전체 개수가 몇 개 인지 모르기 때문에 무한 루프를 돌린다.
while True:
    page = soup.select('div.u_cbox_page_wrap > a.u_cbox_page')
    print('댓글 페이지 개수: {}\n'.format(len(page)))
    # 현재 댓글 그룹의 페이지 개수만큼 반복하며 댓글을 읽어들인다.
    for i in range(len(page)):
        # 다음 댓글 페이지를 연다.
        driver.find_element_by_css_selector(
            '#cbox_module > div > div.u_cbox_paginate > div > a:nth-child(' + str(i + 4) + ')'
        ).click()
        time.sleep(1)
        # 다음 댓글 페이지의 댓글을 읽는다.
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        reviews = soup.select('span.u_cbox_contents')
        for review in reviews:
            print(review.text)
        print('댓글 {}페이지'.format(count), '=' * 80, '\n')
        count += 1

    # '다음'을 클릭해서 다음 댓글 페이지 그룹을 연다.
    try:
        driver.find_element_by_css_selector(
            '#cbox_module > div > div.u_cbox_paginate > div > a:nth-child(13)'
        ).click()
        time.sleep(1)
    except:
        # '다음' 링크가 없으면 무한 루프를 탈출시킨다.
        break

    # 다음 댓글 페이지 그룹의 첫 번째 페이지 리뷰를 읽는다.
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    reviews = soup.select('span.u_cbox_contents')
    for review in reviews:
        print(review.text)
    print('댓글 {}페이지'.format(count), '=' * 80, '\n')
    count += 1
# Out:
# 늦...... 었... 겠 지?????
# 기계는 맞아야한다.
# 까득 먹여놓고 등산이라니 훼스탈 주시나요
# 이런 보상 필요없어
# 그런거였나...
# 교수님 입이 A당
# 옛날에 어떤 사람이 컴퓨터 고치러 갔는데 인터넷 첫 화면이 네이버가 아니라고 고쳐달라 요청 받았다는 썰 기억난다..
# 저래놓고 논문 안나오면 재촉하기스킬
# 안뽑고 지나가면 잡무들이 요다님 다리 붙잡을 듯
# 잡무라길래 교수님마당 잡초뽑기인가..쌀포대나르기인가 했는데 생각보다 더한 잡무들이 있었다..
# 진격의 잡무
# 아쎄이 식고문 실시
# " 해 줘  "
# ??? : 니가 직접 먹고! 판단해.남의 말에 휘둘리지 말고.
# 난 니가 줏대있게 인생 살았으면 좋겠어.
# 댓글 1페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 이마에 저건 결속의 문양인가요?
# 회사들어가서도 업무 과반이 잡무...
# 와 샌....ㅈ....아니...식고문
# 뉴진스의 하입보이요
# 일병이 일 많이한다고 영원히 이등병하겠다는게 맞나..??
# 박교수 보고잇나?
# 주제 너무 귀여워..
# 뭐지 우리 교수님인가???
# ㅋㅋㅋ 눈사람님 잡무도 동글동글해 ㅋㅋ 귀엽
# 탈출이 자퇴가 아니라 졸업이었어? 야... 이 기만자야.
# 전에 연구원? 보고서 입찰 받아서 일하는 곳 알바 갔었는데 원장이 손으로 이면지에 표 그려주면 그거 한글문서 작업하는 일 했었음.. 진짜 오롯이 공부만 하신분..
# 학부연구생이었는데...박사과정에게 맥북에 윈도우를 깔라고 지시하는 교수님...
# 통신병 이였는데 콘센트 안꽂고 컴퓨터 고장나서 안켜진다던 주임원사님 생각나네요..
# 그래도 먹을건 사주시네 ㅋㅋ
# 가위, 네임펜에 발달려서 항상 사야함..
# 댓글 2페이지 ================================================================================
#
# 현직박사과정으로 이번내용은 ㄹㅇ개공감..
# 간지나긴 한다
# 저 모니터 모델이 뭔가요? 거북목 치료에 최고네요
# 저런 교수님이면 사람 많이 델구가세요...  그래야지 음식이 뿜빠이 됨
# 최신걸 어떻게 싸게 사냐고.....😑😑😑😑
# 간접적으로 경험할 수 있음에 ...감사함을...
# 투모니터가 간지도 나고 효율적이긴하지
# 폴더안에 파일이 들어있는거 보면 신세계 느낌일려나..
# ???
# 올해 지도교수님 연구년이라 편하게 한해지났는데 한 화 한 화 볼때마다 2023....오지마십시오.......
# 그래도 저긴 연구실에서 쓰지... 우리는 집에 가져가든데^_^
# 악기바리ㅋㅋㅋㅋㅋㅋㅋ
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 기여어 ㅋㅋ
# 진짜 환장한다
# 댓글 3페이지 ================================================================================
#
# 중요한건 꺾이지 않는 마ㅇ
# 혼자 왔어?
# 재산적으로 여유는 있고 컴퓨터는 잘 모르시는 어르신들 중에 꽤 있음...
# 아 넘 좋아 웃겨...캬캬캭
# 학사생들은 잡무 안하나요? 보통 학사들이 랩 잡무 그래도 꽤 하는것 같던데.
# 잡무 끝내고 틈나는대로 논문 썼는데 졸업시켜준다하고 피드백 안 주는 교수... 진짜 미치겠네
# 오디세이..?
# 진짜 교수란 인간들 손발도 없이 사는듯하네. 이 웹툰 볼때마다 치가 떨린다... 니 일은 니가 알아서 쳐해!!!
# 석사 탈출 했습니다. 그런데 가기로한 회사 입사가 6 개월이 밀렸네요
# 우리교수님이 저러시면 장담컨데 나데리고 다신 밥집 안가시게 될거임
# 그래도 학교에서 저정도하면 회사가면 편해지더라구요 일을 더 많이 빨리 처리할수있는 능력을 획득합니다 흑
# 뭐랄까  대학 조교는 정말  사회나가면 하는걸 미리 체험해주는거 같아
# 니돈으로 니 시간에 세일하는거 골라서 사 제자가 무슨 퍼스널 쇼퍼인가...
# 회사랑 똑같은데..?
# 교수가 진짜 ㄹㅇ사회악이구나 직장에서도 안저러겠다
# 댓글 4페이지 ================================================================================
#
# 당신이 주인공이잖아요! 상관없을리가!
# 전자램지
# 잡'무'....
# 아직 학부생인데 대학원이 거의 혼자서 회계,법무,인사,총무,관리,기획,...연구까지 다하는 하나의 기업체 였군요.그냥 얌전히 취업하겠습니다.
# 와 씨 읽도 싫어
# 아 뒷꼴 땡겨
# 잡무 얼굴 간악해졌어ㅋㄲㄲㅋㅋㅋㅋ
# 아이고 내가 미쳐
# 육성으로 욕나오네
# 누구세요 누구신데 저희 교수님을 사찰하신거죠?!!!! 흐아아아아아아아!!!!!!!!!!!!!!!!
# 홍잡무여
# 교수님 눈빛이 달라보옄ㅋ
# 엄홍길 대장 따라가지 왜 여기 남아서
# 우리는 이걸 노예라고 하기로 했어요
# 잡기무적
# 댓글 5페이지 ================================================================================
#
# 두근두근♡교육부
# 무르는데예?
# 으앙악!!!!!
# 딱 이컷 보자마자 눈사람 귀엽다는 얘기가 첫베댓일줄알았다 ㅋㅋㅋㅋㅋㅋ
# ???:어허~ 그냥 할머니가 주는 음식이다 하고먹어!
# 대사와 글씨디자인의 끝내주는 부조화
# 넘쳐나는 잡무를 매일 처리하다보면 익숙해져서 아무렇지 않게 느껴지며 짬내서 실험도 할 수 있게됩니다. 그러다 어느순간 정신을 차려 주객이 전도된 상황을 인지하고...정신이 버티지 못하면 저처럼 탈주하게 되는겁니다 ㅋㅋㅋ
# ㅠㅠ내가 했던 것들...지긋지긋허다
# 해리포터에 멘드라?였나 쨌든 바시리스크 치료제였던 거 닮았다ㅋㅋ
# "이게 다 자료를 찾는 연습이에요"라고 교수님께서 말씀하셨다
# 으엑.. 개싫다 알아서 다니라고요 친구 없어?
# 잡무 많다고 징징대지 마세요. 원래 개인 연구나 실험은 퇴근 후에 하거나 주말에 합니당 (눈물)
# 잡무...
# 인공지능 주문도 시급하죠 저런 건 로봇 시키고 연구에만 집중하게
# 프린터기 수리(물리)
# 댓글 6페이지 ================================================================================
#
# 저거 홍어 삭힌 거 주는 건가?비주얼이나 표정이나
# 인공지능 도입이 필요하다 저런 거 맡기게
# 잡무카슈미르
# 아 지금 계속 보니까 이 일을 순수한 그림으로 그려주시니 이해가 쏙쏙 되네요. 그 이해한 것은 “대학원을 가지말자^^”입니다
# 근데 차라리 이렇게 솔직히 말하는 교수짱이라면 좀 귀여울지도
# 귀여워 눈사람..
# 종나싫어ㅜㅋㅋㅋㅋ
# 착하넼ㅋㅋㅋ
# 피해가면 되잖아..
# lcd 말고 oled로 사달라시잖아요~
# 잡무 너무 귀여워서 킹받네 ㅋㅋㅋㅋㅋ
# 잡'무' ㅋㅋㅋㅋㅋ
# 석사들아...우리가 매일 컴퓨터 두드리고 있는것처럼 보이지만..잡무 처리중이드란다...
# 아...운전
# 이렇게 불렀는데 컴퓨터 문서가 안 열려서...?
# 댓글 7페이지 ================================================================================
#
# 디벨롭: 뭔진 모르지만 아무튼 더 좋게 하라는 뜻
# 아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# .
# 니가 줏대있게 살았으면 좋겠어..
# 알빠노?
# 2월 졸업하는 대학원생입니다1월에 연구실 이사하고 내일 후드만 먼저 뺀답니다
# 그래서 오늘 혼자서 후드 나갈 길 후드리찹찹 만들었습니다
# 냉장고가 묵직하더라고요
# 마지막 컷에 저런 말을하면 바로 내 잡무가 되어버리는데.....
# 잡무 표정 ㅁㅊㅋㅋㅋㅋㅋㅋㅋㅋ
# 현실이라는 게 참 ..
# 악기바리-!
# 회사 다니면서 대학원 다닌게 다행이네.
# 이정도면 하나 만들어달라는거 아니냐 ㅋㅋㅋㅋ
# 식고문  대힉원생 버전 ㄷㄷㄷ
# 이젠 무섭다
# 댓글 8페이지 ================================================================================
#
# ㅋㅋㅋㅋㅋㅋ 회사도 별반 다르지 않다…
# 참 잡무 없는 교수님이어서 다행이었네요...옆방에서는 새벽까지 못들어가는데 전 같이 술만 마셔주면 되서...
# 아 정말.... 너무 적절한 비유에 무릎을 탁 치고 갑니다. 늘 그렇지만 오늘 특히 탁월하네요 ㅋㅋㅋㅋㅋ
# 하트무 사악해졌어 ㅋㅋㅋ
# 댓글 9개밖에 없는거봐..ㅋㅋㅋㅋㅋㅋ
# 투 모니터 해서 옆에다가도 저장공간 만들어드리면 되겠네
# 위험한 발언인걸?
# job무 가 무럭무럭 자라면 무대리가 되는건가...
# 넘 귀여워...대학원 안갈래
# 대학원 트리 탈 뻔 했는데이거보고 취업했습니다.
# 감사합니다 !!
# 허허 웃으면서 대화하시는데 줄타기 긴장감 오져
# 아니 운전을 왜 대학원생한테...?
# 예전에 핸드폰 문자보관함 꽉 찼다고 폰 새로 샀다는 사람 있었음
# 이정도면 학비를 받는게 아니라 월급을 줘야하는거 아닌가?
# 댓글 9페이지 ================================================================================
#
# 거대잡무...잡무가 거대하면 그것을 잡무라 할 수 있는가...
# 상관이 생길거같아요🐤🐥🐣🐤🐣🐥🐤
# 저거 lg아님? 16:9 두개 가로로 붙혀둔거
# 잡무ㅋ앜ㅋㅋ
# ㅋㅋ입구부테 만만치않쿤!!🐥🐣🐥🐤
# 처음에 연구실 고를때 그래서 등산가서 찍은 사진 있으면 거긴 일단 거르고 시작하라고....
# 차라리 교수님을 사면 안될까?
# 어느 고등학고 만년삼 생각나네
# 외국에서 대학원 다니는데..진짜 이해 하나도 안가네요..교수님은 뭘하는 자리인가요..?
# 나 대학원다닐때는 교수가 빨리와보라해서 갔더니 자기가 흘린물 닦으라는거였...
# 다른 랩 교수님이 imac 쓰시는거보고 주문하시더니 os는 윈도우로 설치하셔서 사용하는 교수님이 내 교수님이다 하시는분 좋아요 눌러주세요
# 거짓말일거같죠? 진짜있습니다.....
# 놀랍게도 저 짓 다 해봄
# 저 모니터 다 지 제자들 과제비(노동비)에서 삥땅치는 겁니다.
# 장첸이랑  너무 비슷해서 소름
# 댓글 10페이지 ================================================================================
#
# 잡무룩...
# 싼데비스탄 씨뿌리기
# 저거 올해 지스타에서 봤는데 ㄹㅇ 웅장함...
# 잡무광공
# 아니 졸업을 하던가 탈출할 생각은 왜 안 하는겨 ㅎㅎ
# 전적대학에 교수학습센터에서 근무할때 교수법 특강으로 강사가 교수들 뫃아놓고 한 말이 아직도 기억에 남는 명언임"여기 교수님들은 본인 분야에서 최고신데 인성은 안좋으시잖아요?"
# 거기에 교수들이 박수 치며 껄껄하며 인정하는 모습이 광기... 그 차체
# 고장난 기계를 때리는 이유1. 원인 불명의 단선이 충격으로 접촉되어 수리 될 수도 있다.
# 2. 확실하게 부숴야 새로 살 것 아닌가?
# 아무나 박사하는게 아니구나. 온갖 멘탈을 해탈해야하는구나
# 기업 연계 과제거나, 국책 연구 과제겠지........
# 저거 조홍나 비쌈ㅡㅡ..나 설치기사인데 삼성꺼 저거 300넘어ㅜㅜ
# 그리고 엄청 무겁고
# 교수는 돈벌어서 뭐하는데?
# 대출회사 무과장만 떠올랐는데 이젠 잡무가 떠오르겠군
# 이게 돈야랄?
# 거대 잡무면... 연말 과제 연차계획서나 결과보고서 작성이겠네 아 ㅋㅋ
# 등산캐릭터 킹받네ㅋㅋㅋㅋ
# 댓글 11페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 그런 무서운 말을...
# ㅎ  ㅎ   A
# 정치하고 싶어하는 교수님도 정말 거대한 잡무임 ㅋㅋㅋㅋ 방송, 라디오 등.. 가방수니부터 선거유세까지 따라다님
# 잡무..ㅋㅋㅋㅋㅋ 아놔 킹받는데 귀여워요
# 우리 연구실은 내년부터 행정쌤이 온대요...키햐
# 싼데비스탄
# ㅋㅋㅋ 잡무인데 라떼가 같이 있네?
# 뒤에 🦉 땜에 안될듯 ㅋㅋㅋㅋㅋ
# 양x치니...??
# 막내가 상관 없는 일이 어딨어ㅋㅋㅋ 서류 제출이라도 시키겠지ㅋㅋㅋ 게임 퀘스트 같음 여기 가면 여기 아니니까 저기 가세여 저기 가면 아 이거 어디가서 뭐 받아오세요ㅋㅋㅋㅋ
# 실적정리 인가... 박사형들이 정리하면 내가 내고 그랬는데ㅋㅋㅋ
# 그래서 리스트로 쫙 뽑고 상품별 성능을 작성한 다음 왜 이걸 골랐는지 PPT를 만들었죠...
# 나도 저걸 하면서 논문 얘기를 했지... 1학기인데 뭔소리인가 하면서 들음ㅌㅋㅋㅋㅋ
# 천천히 빨리 꼭꼭 씹어서 먹어...
# 우리 교수님도 캔디크러쉬 하고 스파이더 카드놀이 하는데 모니터가 작아서 잘 안된다고 바꿔달라 했는데...
# 댓글 12페이지 ================================================================================
#
# 우리는 문방구 바로 앞에 있으니까 직접 가서 사오랬는데...
# 특정 분야의 전문가라서 프라이드 높은 사람이 자기 분야 아니면 바보인데도 존심부리다 참사 일어나는 경우가 종종 보이지
# 대학원....잘은 모르겠지만 가면 안되는곳 이라는건 확실히 알겠네요
# 표현 귀여운거봐 ㅋㅋㅋ
# 키링 예쁘다고 아우디&벤츠 사는거네 ㅋㅋㅋㅋㅋ
# 옆방 교수님이 혹시 BJ신가요?
# ??: 교수님을 차기 전에 그만하시죠?
# 잡무 : 계획대로 ( ㅋㅋㅋㅋㅋ)
# 시약확인 진짜 날잡고 랩사람들 전부 불러모아서 A-z 배열 / 4,6류 분류 / 온도별 분류 / cas no. lot no. 정리 시킨 후에 엑셀로 매번 시약 올때마다 정리하게 두달정도 갈구면 좀 편해집니다....
# 거대 잡무: 등급 :희귀 .성능 :더 길어진 더 까다로워진 구속시간과 해금방법 희귀성이 있어 몇마리 안 걸리지만 한마리 만으로 벅차 만반의 준비가 필요하다 더 상위급 잡무로는 진격의 잡무, 진격의 거인의 잡무가있다
# 눈사람 너무 귀여워ㅠㅠ 진짜 볼 말랑 할거 같아ㅠㅠ
# 뭘 그와중에 파일 위치 모니터에서 바로 찾으시던데. . .바꿔드리면 한동안 적응기간 필요함
# 저딴게 무슨 보상이야ㅠㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 잡무레이크 미친ㅋㅋㅋㅋㅋㅋㅋㅋ
# 댓글 13페이지 ================================================================================
#
# 와 진짜묘사력 지린다..
# 작가님 이제 진짜 작가님이 되신거 맞는거 같아요.
# 도전 시절에서 랩업 두단은 하셨군요.
# 잡무....
# 플래그 빡씨게 어서오고~
# ㅁ...모르는데용그럼 저는 이만...
# 더 디벨롭...! 화가나네 ㅎㅎ
# 아...그..발언...
# 자까님 좀 그림체 톤이 밝아지셨죠? 전 그렇게 느끼는데 좋아요>< 채도가 올라갔달까,,,
# 와 대학원생들은 이런거 모르고 들어갔다가당하는거아냐 ㄷㄷㄷ
# 이럴땐 0고백 1차임 시전을
# 연구는 핑계고 그냥 개인비서가 여럿이네 ..
# 와씨 실화??
# 그러고 보니 우리 교수님도 등산... 테니스.. 거의 산악인..
# 크게 상관 있어 보이는데요??ㅋㅋ
# 내돈 아이갚니?
# 오빠 정신 안차리지?
# 댓글 14페이지 ================================================================================
#
# 광고가 있나??ㅋㅋ
# 교수님이 이번에 구매하신 모니터가 어느 제품이죠? 커브드가 위아래로 된게 멋져 보이시는데....아시는분?
# 괜찮은 연구실은 사무 보조 사람 한명 씀. 좋은 연구실 고를때 지표중 하나
# 제가 먹어드리겠...
# 난 대학원시절..밤 12시 30분에 혼자 복사를 하다 복사기 고장나서 복사기한테 울면서 빈적도 있었음..인간이 기계에 무릎을 꿇고..그러나 그런건 아무일도 아님..
# 응애 나 애기교수
# 그리고 저 정도 거대 잡무는 아니지만 학기중 언제나 있는 수업조교일.. 시험 및 과제 출제 채점
# 학과행사준비.. 실험실 동창회 모임 (주소록정리  초청장 돌리기 장소 섭외)
# 교수님 출장 중 강아지 산책시키고 밥주기 정말로 해봤다
# 저래서 대학원생들은 잡무가 없는 주말이나 연휴에 오늘은 쉬자.. 가 아니고 오늘은 연구만 할 수있다! 하고 좋아합니다. 주말에도 잡무가 있을 수도 있지만요..
# 이거 해리포터에 나오는 그거같다ㅋㅋㅋㅋㅋㅋ
# ??: 니가 먹고 판단해 난 너가 줏대 있게 인생 살았으면 좋겠어
# ㅋㅋㅋㅋ
# 그 발언...
# 저렇게 시다짓만 죽도록 할거 같으면 그냥 학위 안따는게 나을듯
# 댓글 15페이지 ================================================================================
#
# 니가 찾아
# 사주면 잘하니 뭐라할수도 없음ㅋㅋㅋ
# 니손으로 모니터 하나 못사니
# 미쳨ㅋㅋㅋㅋㅋ그걸 이렇게 비유하네
# 이 교수님은 귀엽기라도 해서 다행임ㅋㅋㅋ
# 작년 크리스마스날 ,,, 출근해서 박사과정 쌤이랑 둘이 시약 900개 정리한 기억이 나네요 ,,,, 도대체 왜 1980년대 시약이 1/3인건데.......... 왜 lot no.나 CAS no. 둘중 하나가 없거나 다 없는건데 ....
# 관악산ㅋ
# 대학원 그기 돈이 됩니까
# 오디세이 아크 같네
# 비슷한 캐릭터를 실제로 본 적 있어서 이게 진짜 실화인지 아닌지 너무 헷갈림 ㅠㅋㅋㅋㅋ
# 이제 박사도 2명이나 빠졌는데...
# 그냥 빨리 따고 뒤도 안 돌아보고 나가서 다신 얼씬도 안 하는것이...
# 데이팅 블랙리스트 올려버려
# 같은건데 어떻게 싸... 오르면 올랐지 "싸게"가 가능한거냐고
# 댓글 16페이지 ================================================================================
# 이걸 해주는 사람을 돈주고 따로 고용하면 해결될 일이지만 대학원생을 갈아넣으면 비용 0원
# 연구실.... 안전....점검.... 소방처....주관....
# 싼데비스탄...
# 잡무 진짜... 너무 열받아요 일반 직장인인데 일50 잡무50 시키면 대체 사람 몸이 2개도 아닌데 어떻게 다 하라는건지 싶고
# 내가 이런거나 하려고 들어왔나 싶고...^^
#
# 그렇다고 일을 줄여주는 것도 아니고 진짜 잡무라서 현타오고! ㅋㅋ 개빡침
# 싼데비스탄...
# 거대 잡무 = 거대한 장비 구입, 연구실 안전점검, 대청소 등이 있죠
# 뿩! 이 프린터기는 너무 바가지를 써서 우리 할머니가 샀다해도 믿겠다!
# 사람들이 대학원에 갈까봐 그리신듯
# 가스라이팅 당했네
# 이거 그거잔앝ㅌㅌㅌㅌㅌ 그 미국 요리사
# 샘숭 오딧서이
# 진짜 yuji는 박사과정 어케 이수한거?
# 잡무 넘귀엽ㅋㅋㅋㅋㅋ
# 근데 듀얼모니터하면 바탕화면에 더많은 파일을 넣을수있긴함
# 아니 이번 화는 진짜ㅠㅠㅠㅠ 매 화가 공감이 가네요... 작가님 진짜
# 댓글 17페이지 ================================================================================
#
# 악 ㅋㅋㅋㅋ 너무 기발해서 빵 터졌어요 ㅋㅋㅋ
# 교수가 만든 회사는 절대 들어가지 마라 그건 회사가 아니라 또 다른 이름의 대학원이니까
# 대부분의 회사도 저렇습니다 과제 돈으로 사면 다 지들 돈 아니라고 막 쓰죠
# 연구실 보조 인력으로 경리를 뽑아!!!!
# 교수님의 잡무1: 주말에 총장님과 데이트하기
# 으
# 눈사람이 여기 왔어야하네
# 상관이 있을 것이다
# 교수광공ㅋㅋㅋ
# 교수님과 단 둘이 외출이라니 저라면 사양할게요
# 군대에서도 최고위 고문은 식고문이였지.
# 음 이 분은 학문과 관련된 지식만 입역되어 있고 생활에 필요한 모든 지식이 그걸 대체한다는 느낌이야
# 러쉬앤캐쉬~
# 저 정도면 잡이 아니지않냐고ㅋㅋㅋ
# 내가 제일 싫어하는 무는? 잡무.
# 댓글 18페이지 ================================================================================
#
# 산책만씩한거 하는데 뭐 저렇게까지
# 회사 생활을 하다 대학원에 가도 저런 잡무를 하는 상황이 있나요? 졸업하고 몇년 있다가 대학원 간 사람들이 몇명 있는데 학사 졸업하고 바로 간 어린 학생들에게만 오만잡다한 일을 시키는 건지ㅠㅠㅠ 궁금하네요!!
# 아 오늘 건  진짜 ptsd 지린다...
# 교수 와이프랑 교수 지인 석사 논문 대신해줘 봤다. 하............뉭미
# 아 개웃곀ㅋㅋㅋㅋ
# 아 미친ㅋㅋㅋ 다 들어본 거라서 소름 돋아
# 회계 선생님 감사합니다
# 등산 참 좋아하네 참나 ㅋ.............(과거가 떠오르네....
# 오골계 귀엽네요
# 왤케 불량해보이냐 무주제에
# 이 분 고려대 교수님 맞네요. 얘기 들어봤는데 기상천외한 썰 엄청 많아요. 지나가는 학생 붙잡고 앉힌 다음에 전공얘기 하시고, 밥 먹자고 하신 뒤 대학원 납치가 아니라 같이 먹을 사람이 없다면서 밥만 드시고 전공얘기 하심. 실제로 엄청 똑똑하셔서 그 분야에서는 연구실적 엄청나다고하더라구요. 인성이 나쁘지도 않으시고 권위적이지도 않으신데...저런 엉뚱한 행동들을 엄청 하신다고 하네요. 오히려 대학원생들이 질문을 꺼린데요. 한 번 질문하면 엄청난 지식을 주입당해서... 질문에 대한 답변이 거의 1시간이래요. 그래서 대학원생들이 질문을 잘 안 드리고 스스로 찾아본다는 웃픈썰도 들었네요
# 보상이 아니라 부상... ㅠㅠ
# 안녕하세요 한달에 회의비 30개 쓰는사람 입니다.
# 그날, 대학원생은 떠올렸다.교수 님들에게 잡무에게 당해왔던 공포를...
# 랩실 속에서 갇혀만 살았었던 굴욕을...
# 상관 없 .. 을 ㄹ..가 ..
# 댓글 19페이지 ================================================================================
#
# 아 귀엽네ㅋㅋㅋㅋㅋㅋㅋㅋ
# 제발 굿즈로 잡무 인형 만들어주세요 ㅠㅠㅠㅠ 잡무 생길때마다 죠낸 패게요 ㅜㅜ
# 우리 실험실 주관연구아니고 다른 연구실 과제중에 일부만 일거리 떼와서 교수님만 연구비받는 과제 하라고 시키면 진짜 그만큼 짜증나는 개잡무가 없음!!!!!!!!그렇다고 주관연구 연구비도 학생이 받진 않음 공금처리임. 근데 실적으로 이름넣은건 써먹을 수 있어서 그나마 나음.
# 잡무는 무일 뿐이다 먹어치워!!! 라고 말하고 싶지만 겪어본 사람만 아는 잡무는 박사과정에서 방어를 어느정도 해주다 아 미안 이러면서 박사 과정들이 물밀듯 빠져나가는 순간 석사 과정들은 말 그데로 헬을 보게 되지 하하핫 그것이 바로 대학원이다앗 대학원은 탈출하기 직전까지도 잡무가 ㅈㄴ 많아서 처리했나? 하면 또 나오고 처리했….하면 또나오고 계속 나옴
# 진짜 high한 테크네
# 그 해리포터에 나오는 그 이름이 뭐더라 아무튼 그 시끄러운 풀 닮았네요
# 연차보고서, 과제제안서, 진도실적보고서 등등... 대학원생도 연말이 젤 바쁩니다...
# 전기 사용하는 물건이 고장났을 경우 한국인 특 : 일단 때리고 봄 때렸을 때도 수습이 되지 않을 경우엔 분해함 분해해도 상황 수습이 안될 경우에는 고장난 물건 처분함
# 연구실 안전관리 점검올때도......일지적고 스티커붙이고 시약정리하고......진짜 개 귀찮음
# 이런 사례를 하도 보다 보니 어느샌가 "이정도면 약과지"라고 생각하고 있는 대학원 갑질에 익숙해진 내 자신을 봄
# 잡무가 진짜 모든 일 효율 저하시키는 주범.
# 플레그야 그거
# 아오 디아블로 광고 ㅋㅋㅋ 그녀의 지옥을 맞이하라  (잡무 ?)
# 그리고 과제카드로 결제하면 제품사진들 전부 정리해서 내야되는 것도..
# 그 대출광고캐릭터같다ㅋㅋㅋㅋㅋㅋㅋㅋ
# 댓글 20페이지 ================================================================================
#
# 교수님께서 필요한 파일과 불필요한 파일을 정리를 하지 않으셨기 때문에 이것은 엄연히 교수님 때문 입니다 그럼 수고링
# 아아...
# 부럽다 ㅠ
# 저거 600아니였너 ㅅㅅ꺼
# 꺼져줘 제발
# 회사에 교수 있으면 프린터 해달라고한다...잽알...
# 상관이 없을리가없죠..
# '영원히'
# 아쎄이-!
# 누군지 알고싶지않아요..
# 하지만 나중에는 깨닫죠 어차피 내돈이 아니라는 사실을..
# 근데 교수님이 뭘 많이 하셔서 >잘되셨다면< 나중에 학생의 이력에도 00교수님 제자 타이틀이 빛을 낼 수도 있죠!
# 교수님과 데이트면 환승연애도 쌉가능..
# 항상 1차 방어선은 뜷리는 법.
# 본격 대학원 입학 방지 웹툰
# 댓글 21페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 저 일이 잡무이다에 나의 손모가지를 걸지
# 눈사람 귀요미..
# 석사 3년인 사람봤음... 개불쌍
# 미국 실험실은 대부분 랩 매니저가 있어서 잡무가 좀 덜한데,  울 실험실은 매니저가 그만둬서...으헝 ㅠㅠ
# 아닠ㅋㅋㅋㅋㅋㅋ 맨드레이크 뭔뎈ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 교수님돈으로 내돈으로 살순 없지만 써보고싶었던거 지를수 있죠 ㅎㅎㅎ 전 가끔 지름을 유도함
# 나는 오히려 좋을듯??
# 큰 잡무라면 과제 관련 업무일 거 같은데...그럼 비주얼 자료 만들기 담당으로 갈려나갈 가능성이 매우 높겠네요 ㅎㅎㅎ
# 초반에는 그냥 낄낄대면서 봤는데 언제부터인가 눈가가 촉촉해짐...
# 잡무를 뽑아버리고 싶은 무로 표현하시다니.. 작가님은 천재예요
# 두근두근 문예부- 대학원 편
# 잘 샀네 ㅋㅋㅋㅋㅋㅋㅋ
# 학부생 입장에선 학부 수업 시험 출제랑 채점이 무척 궁금합니다!!
# 이제 있어질 예정
# 댓글 22페이지 ================================================================================
#
# 20만원짜리 컴퓨터도 아니고 ㅋㅋㅋㅋ
# 저 거대잡무 백프로 실험이나 실습 수업 담당임
# 사람 제일 빡치게 하는 건 자기들끼리도 이랬다저랬다 하는 한국연구재단...너네 답변이라도 일관적이어야 참고해서 행정 처리를 할 거 아니냐고 ㅂㄷㅂㄷ
# 아니 ㅋㅋㅋㅋㅋ 저렇게 무시무시한 말을 저렇게 상큼하게 말하지 말라고요 ㅋㅋ큐ㅠㅠㅠ
# 듣도 보도 못한 잡무 ㅋㅋㅋ큐ㅠㅠㅠ 정체를 확인하기 두렵다...
# 본인이 책임질 수 없는 똥은 뿌리지 말자...^^
# 시약확인... 아니 유통기한 지난건 알아서 버리라고,,, 몇 년전에 끝난녀석은 왜 있는거야.... MSDS까지 찾아서 정리하고,,,
# 라이라이 차차차
# 근데 저런거는 조교가 안 함?
#  "별것 아닌 것 같은데" ㅋㅋㅋㅋㅋ큐ㅠㅠㅠ 대학원생의 촉은 틀리지 않았다고 한다...
# ㅋㅋㅋㅋㅋㅋ 세 분 표정이 ㅋㅋ큐ㅠㅠㅠ
# 무과장은 귀엽기라도 하지 이건 진짜
# 석사,박사 ㅋㅋㅋ 진심 공감 됩니다
# 공대학원생입니다...내일 교수님과 세미나가 있습니다
# 끝나고 회식도 있구요
# 전부 제가 예약하고 준비합니다
# 살려주세요
# ???: 신경쓰어요
# 댓글 23페이지 ================================================================================
#
# 배부른데 볼이 홀쭉하세요...
# 우웩
# 저거 진짜임
# 궁금한게 대학생들 수업이나 실험조교 또는 수업자료 만드는건 잡무에서 어느정도 난이도인가요? 의외로 담편까지 그내용은없어서
# difco
# 아씨ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ뭐하자는거에요
# 뭔 애도 아니고 진짜
# 하 등산 날라다니는거 보고 다른 교수님들도 불쌍히 여기시던데...
# 누가 5야?
# 난죽택...
# 아 조그마한 뿌엉이 개겹네ㅋㅋㅋㅋㅋㅋㅋ
# 학회 장소 선정 답사 다녀온 사람 여기있어요...
# 이거 해리포터 멘드레이크 뽑는 그건가 ㅋㅋㅋㅋ
# 시스템을 빨리 종료하십시오
# 거대 잡무를 준다면 그동안 박사과정들이 해오던 잡무를 석사들이... 나눠.... 크흑...
# 댓글 24페이지 ================================================================================
#
# 지금 막 드는 생각 💡 확 저걸 팔아? 아님 부실까?
# 아방방 교수: 약 줘!
# 순수악 등장
# 군대하고 다를게 없잖아
# 궁금한게 저거 안 뽑고 지나간다는 선택지는 없나요?
# 아..ㅜ 무.. 잡..무
# 잡무의 세계
# 보스몬 잡무
# 크... 저도 랩 운영비 관리하느라 엄청 빡셌던 기억이나네요. 제가 나름 쓸모 있었는지, 교수님이 박사 하라고 꼬시는게 더 무서웠어요.
# 실험기구들 외부업체한테 대부분 맡기지않나?
# 신이 대학원을 만들때학문을 쪼오오오금 잡무 30컵.... 어잌후 🩸🩸티를 부어버렸네...
# 아직도 잡무는 소리네고있네
# 진짜 과학은 천재지만 0과 1은 모른다던 교수님 맞으시군요...
# 양심 눈치도 안 주셨나
# 뿌엉 가디언
# 댓글 25페이지 ================================================================================
#
# 뭔가 몽총하게 생겼다
# 와 저 씨봐라
# 와 씨 웃지 마 무서워 ㅜ ㅜ ㅜ
# 눈사람씨 ... 녹았네 ㅜ ㅜ
# 그럼 니가 사 ㅜ
# 아니 저럴 거면 눈사람씨를 데려 오지 ... ㅜ ㅜ ㅜ아니면 코선배나 ... 최소 두 명이라도 ㅜ
# 어우 뭐 이런 끔찍한 ㅜ
# .... 저 주말에 아플 예정이라서요 ....하하 ^^ ;;;;;
# 아 좀 ;; 오반데 ㅜ ㅜ
# 아 .... ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# ..... ? 이게 뭔 소리야 진짜 ;;;;;;
# ❓❓❓ 알아서 사세요 제발 ㅜ ㅜ ㅡ
# 와 진짜 잡다한 업무다 ........저걸 왜 ;;;;;
# 아니 저런 것까지 해야 돼 ??? ㅜ ㅜ ㅜ
# ??? :  치워
# 댓글 26페이지 ================================================================================
#
# 띠바 완전 나잖아여???? 교수님아 보고있니????
# 머싯어..
# 저정도면 잡무보다 잡부가 어울리는 단어같아요온갖 잡일 다시키는 교수님 ㅠ
# 깍두기라도 담아서 치워버리고 싶네요
# 맞아욬ㅋㅋㅋㅋㅋㅋ 가위는 매번 대여섯개씩은 사는데 항상 어디로 사라지는 건지 모르겠엌ㅋㅋㅋㅋㅋ
# 데이트폭력ㄷㄷ
# 요다님이었다면 어떻게 됐을까요...
# 다신 모자르다 소리 못하게 75인치로 사주세요
# 그 놈의 등산 아주 그냥 산을 깎고 깎아서 과속방지 턱으로 만들어야지?
# 조만간 트레이더처럼 모니터8개 쓰시는건 아닌지
# 진짜 저 교수님은 암벽등반 시켜야한다
# 진심 뿍쳐서 '왜이리 힘든 거지....' 생각하다가 박사과정들 보면 안쓰런 표정으로 '저기보다는 낫지......'라는 생각이 저절로듬..
# 진짜 잡무뿌리기가 세상에서 제일 나쁨...... 아직도 그 때 생각나면 화남! ㅇㅅ"ㅇ
# 우리나라 대학원...진짜...하아...
# 쿠키 '더' 먹어
# 댓글 27페이지 ================================================================================
#
# 그러는김에 니가 해
# 등산이요? 시베리아 등산 제2탄?
# 아아아악 작작 뿌려요
# 귀엽다 진짜.
# 이럴거면 그냥 비서를 두지
# 잡무가 아니라 멘드레이크네
# 26년차 윤석사다.우리 때 악기바리는 이정도였다
# 보통 안믿기면 실화임...
# 말도안돼..
# 싼데비슷한
# 이래놓고 연구 진행 느리면 이제까지 뭐했냐고 뭐라함....
# 근데 그거랑 별개로 바탕화면에 아이콘 많은게 그렇게 나쁘진 않아요. 바탕화면의 쓸모를 뭘로 생각하냐 따라 다른데, 굳이 예쁜거 필요없이 컴퓨터가 켜지자마자 뭔가 빠르게 시작되어야 하면 저 상태가 작업효율도 높고 좋습니다. 그 안에서 뭐가 있나 정말 심혈을 기울여 찾아야 하면 탐색기 같은 앱에서 바탕화면을 열어서 찾아보면 될 문제고..
# 우리 교수님은 액정 깨진걸 수리업자한테 물어보려고 스크린샷을 찍었는데 깨진 자국이 안 남는다고 우리에게 찡찡댔다
# 삼성 오딧세이네..
# 댓글 28페이지 ================================================================================
#
# 저거 딱 봐도 모니터 두개 이어붙인 느낌입니다만 교수님..
# 무사와요
# 진짜 가지가지한다....
# 멋있긴해서 어ㅣㅇ없음 ㅋㅋㅋㅋㅋㅋㅋ
# 그럴리가...
# 더 디벨롭 ㄷㄷㄷㄷㄷ
# 중요한건 꺾여버린 마음
# 싼데 비슷한...
# 보통은 교수님이 부른다 하면 섬찟하는데, 양아치님 얼마나 해탈했으면....ㅎㅎㅎ
# ???: 너 교수한테 납치 된거야
# 범죄도시가 여기서 왜,
# ???: 니가 직접. 먹어보고. 줏대있게 판단해. 남의 말에 휘둘리지 마.
# 보통 저런건 막내가...^^
# 뿌엉 인형이나 시계 나오면 좋겠다 책상에 놓으면 쟤 눈치 보여서 딴 짓 못할 듯
# 저 그림만 보고 어떤 정도인지 판단하는 사람들은 대체 무슨 일들을 겪었던 거지
# 댓글 29페이지 ================================================================================
#
# 그 와중에 방어준비! 라고 오더하는 사람이 코가 아니라 뿌엉이에요 ㅋㅋㅋ
# 잡무 손은 공손한데 표정은 킹받네ㅠㅠㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 저 교수님은 공대 교수님이 아니라 지질학과나 천문학과, 생물학과(생명공학x) 이쪽 교수님이 되었어야 했다
# 양아치 누님 왜 이렇게 귀엽지 ㅋㅋ
# 저정도면 양반이에요... 본인 사업체로 새로운 컴퓨터랑 기기들 다 들고 가고 연구실은 쓰레기 컴터만 남겨둠.
# ??? : 니가 선택한 랩실이다!!! 악으로 깡으로 버텨라!!!
# 제안서 아님 연차보고서 같은데...
# 그래도 연구비는 많나보네ㅋㅋㅋ
#  ㅇ    ㅇ     A
# 그거 같네 인스타 릴스에서 사위가 장모님한테 사줘! 하는거 ㄴㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 입꼬리 심상치 않은데
# ???: 아쎄이~
# 사랑무
# 작가님.김양에피소드보고싶어요ㅠ!
# 무ㅏ야 진짜 무였어?
# 댓글 30페이지 ================================================================================
#
# 님들... 그거 아세요...?왕고는 저 잡무를 혼자 다 처리했었대요..!!
# 저걸 누가 해? = 니가 함나까지 오겠어? = 나까지 옴
# 여러분 안 믿기시지요? 이게 대학원에선 비일비재합니다.
# 싼 거 찾은 거야?
# 큰사업 과제제안서아닐까요? 기간길고 돈많이주는거 ..ㅋㅋ
# 이하!늬다!!!!
# 최강체이자 최약체
# 실험용품비 관리 예산짜기 지출증빙 회의비 관리 안전관리 등등등 ..
# 보통.. 그러면 상관이 있더라구요
# 대학원뿐아니라 현업왔는데도 잡무때문에 내일 늦춰지는 그 기분...
# 바닥 밑에는 언제나 지하가 존재했다....
# ??? : 영원히 석사!?? 졸업하기 싫어???(^-^)
# 이번회차에서 제일 평화로운 컷이네요~~
# 감사 방어 증빙 필요해서 원하는대로 사려면 요령껏 잘 서류 꾸며야함 ㅋㅋ꙼̈ㅋ̆̎ㅋ̊̈ㅋ̌̈ㅋ̆̎ㅋ̊̈ㅋ̌̈ㅋ̄̈ㅋ̐̈ㅋ̑̈
# 불행해보이는 눈사람 너무 귀요워......
# 댓글 31페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 로아랑 콜라보한 모니터 입니다
# 대학원에서 졸업한게 아닌데 웃는 사람은 조심하라고 하지
# 이번에는 라떼를 그렸네요. 요다님이 맡을 거란 징조입니다
# 두근두근 러브러브~대학원에서도 사랑할 순 없을깡?~디 오리지널☆
# [선택지를 골라주십시오]1.밀당고수마냥 튕기기- 미안하지만 난 이만 가볼게요(패널티:석사학위박탈)
# 2.친절하게 행동하기-함께 해서 너무 좋네요(패널티:내 존엄성)
# 3.단답으로 무심하게 굴기-네..(패널티:교수님이 그냥 아니꼽게 느껴, 졸업 1년 연기)
# 내 새끼가 이번에 대학졸업을 하게 됐는데 여애인 좀 사귀여봐야지~^^ 그냥 아는 사람 중에 소개좀 시켜주면 되는데..
# 큰 건 바라지 않으니까 대충 연예인 박보검이나 손예진 닮고, sky 졸업생이면서 대기업 어디든 들어간 대리 이상 22살쯤이면 되겠어^^
# 잡무=교수 인가요?
# 병앓슴
# 저 개미 더듬이가 양이 잡을 수 있는 고삐이길
# 우리금쪽이~폰바꾸려는 초딩잼민이처럼 굴면 못써~
# 교수들만 보다가 존댓말쓰는 장첸무를 보니까 설레네. 정말 내가 미쳤지ㅠㅠ미쳤어. 치킨 시켜먹어야겠네
# 일단 개기기(???)가 가능한것부터가 평타는 치는 교수라는 거......
# 무야호~~~
# ??? : 진실의 방으로
# 악기바리 ㅋㅋ
# 댓글 32페이지 ================================================================================
# 먹이는 빵이 옆면으로 보면 하트모양이네
# 순간 저도 모르게 멋지단 생각.그리고 검색해본ㅎㅎ
# 왠지.....무를 볼때 마다 잡무가 생각 날것 같아요
# 오랜만에 우선배 등장ㅎ
# 싼데....좋은거 없어요...
# ㅋㅋㅋ물리치료....표현이 참 너무 귀여우심
# 아 ㅋㅋㅋㅋㅋㅋ
# 우리 교수님 참 맑으시다...참 맑으셔
# 싸게는 안되요
# ㅋㅋㅋㅋㅋㅋ
# 잡무라서 뽑아야했던거구나
# 밟으면 안되용??피해가면.
# 영원히 석사과정 하면 치킨도 사줄 수 있음
# 상사 최악의 취미는 아무래도 등산인거 같아...
# 와 교수님은 숨이 턱 막히면서 묵직하게 짜증났는데, 얘는 그냥 짜증나네요..
# 댓글 33페이지 ================================================================================
#
# 저걸 뭔 수로 싸게 사 ㅋㅋㅋㅋㅋㅋ
# 잡무 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 감시뿌엉
# 호러물 아니고
# 로멘스 + 스릴러 = 로멘스릴러
# 해상도 높은 걸 사면 바탕화면이 비례해서 크기가 늘어나긴 합니다. 그냥 정리를 해주세요 제발!!
# 저기서 박사과정들 방어준비가 마음에 걸리네요... 라떼 선배는 자기도 석사라고 빠지시는거 아니겠죠???
# 노예 복장인가요??ㅠㅠ
# 사무용품 구매는 잡무중에 그나마 재미라도 있는 잡무죠 ㅎㅎ 남의돈으로 쇼핑하는 기분
# 교수님 호출에 다른 잡무들 반응이ㅎㅎㅎ
# 모르면 안됩니까ㅠㅠㅠ
# ??? : 정신없어할 때 지도교수가 호랑이처럼 달려와서 가슴팍을 걷어차고 귀싸대기를 날렸다
# 살려주세요
# 의외로 예의바라
# 내가 저런 실험관련 잡무가 싫어서 이론쪽 랩으로 갔지. 단, 이론쪽은 졸업이 느려짐
# 헨젤과 그레텔 잔혹동화 게임에서 무 뽑으면 막 저렇게 소리지르는 거 생각남
# 댓글 34페이지 ================================================================================
#
# 잡무는 석사들에게 맡기라구~!
# [System] 교수님의 잡무 뿌리기 시전으로 인해 일 효율 능력이 감소하였습니다. 대학원 탈출이 늦어집니다.
# 잡무 표정 조낸 킹받네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 산단은 정말 필요 악임. 산단 없고, 예산 막 쓰라고 규정 없었으면 교수들 뒷주머니에 돈 다 챙겨넣었을껀데 산단이라도 있으니 그짓을 잘 못하긴 함 (근데 매년 하나씩은 걸리더라? 욕심만 줄이면 정년보장인데 왜 그러시는지... ) 근데, 예산처리는 학생이 하니 귀찮은 노릇
# 이런건 눈사람이랑 코끼리가 제격인데
# 다들 놀라는거봐 ㅋㅋ 사람이아니라그런가
# 진짜개공감.... 석사신입여러분ㅜㅠ 박사선배들이 성격파탄자같고 다시키기만 하는 예비싸이코패스같죠?ㅠㅠㅠㅠ 맞긴한데 교수님과제랑 직결된 잡무들은 박사들이 합니다ㅠㅜㅜㅠㅠ 랩바이랩이긴한데 대학원탈출일기 처럼 석박사가 여럿있으면 보통 그래요.....
# 상관 없을 수도 있는데 어쩔 수 없이 튀는 잡무 쪼가리가 데미지 엄청 클 것이다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 어디서부터 잘못 된거지?.....
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 모니터(32인치, 베젤은 삼지나 엘성 것처럼 얇아보이면서 걔넨 너무 비싸니까 적당히 저렴한 중소기업꺼, 오래 봐도 눈 아프게 하는 기술도 있다는데 그것도 들어간 거, 아 그리고 뭐 패널 뭐시기 영화볼 때 좋은거 있다니까 그걸로 하고... 그 뭐야 옆 방 문 교수 모니터는 무슨 공중에 떠 있던데 내껀 안되냐? 이미 갖고 있는 것도 되는지 확인해보고 그것도 해줘라. 포트? 그런거 몰러 알아서 할 수 있잖아 그런 것도 정해줘야 하냐? 졸업해서 어떡할래을 시작으로 잔소리 주절절주주절...) 주문하는 거잖아? 잡무치곤 단촐하네
# 산단 한 번 다녀오는 게 뭐가 힘드냐고 할 수 있겠지만.. 저희 학교는 산에 지어졌죠...
# 그아아아아아아악 나는 연구를 하러 대학원에 갔던거지 예산을 짜주러 갔던 게 아니란 말이다 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ
# 앙돼!
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 귀여워
# 댓글 35페이지 ================================================================================
#
# 여윽시 명예 방장 뿌엉님.. 어둠의 뿌사모단들의 마음을 불살라버리네..
# 악기바리. 대학원생의 악기를 키우는 전통.
# ㄴ
# 아무리 봐도 이 만화는 V머리를 조심해야 돼...
# 이게 바로 말로만 듣던 얀데레와의 데이트?
# 우리 헤어지자
# 프린터기 종이 낀게 제일 극혐.. 보이면 빼기라도 할텐데 엄청 안쪽에서 껴서 안보일때 개빡침..ㅜㅜ
# 나다싶으면 튀어나와......
# 대식가면 가능할..수도..? 아닌가..?
# 아닛.. 우리만 그런건 줄 알았는데.. 다행😌
# 순간 공중에 떠 있는 신문지 인줄ㅋㅋ
# 뭘 바탕화면에 깔았길래 꽉 차..? 새로 모니터 산다고 뭐가 달라짐..? 걍 폴더 하나 만들어서 다 쳐넣고 뭐 넣어놨나 따로 메모해놓으면 안됨..?
# 내 하월빈 잡무췐이야!!!!
# 뿌우엉
# 사악한 잡무무리다아
# 댓글 36페이지 ================================================================================
#
# 보... 보상이라고...?
# 나다싶!! 나다싶!!
# 교수님 일이라니까 다른 잡무들도 양보해주네ㅋㅋㅋ
# 스티브 잡무
# 순무
# 겠냐고요ㅜㅜ
# The욱 The욱 디벨롭시키기
# 왜 스윗해?
# 시약 리스트에 cas no.랑 lot no. 랜덤으로 바꿔적은 파일 준 자식 생각나네...지 냉동칸에 시약 꿍쳐놓고 쓰던 자식도 같이 생각나네...
# 투블럭의 여집합
# 결국 사셨엌ㅋㅋ
# 다들 잡무 쳐다보는거 넘 커엽,,
# 진짜 다 시켜도 되나요??
# 프린터기 특징대부분의 경우 잉크가 없거나 전원을 안켰거나 종이가 낀 거임.
# 댓글 37페이지 ================================================================================
#
# 이게 말로만 듣던 팀원들하고 라면 먹기 vs 부장님하고 단 둘이 비싼거 먹기 구나 물론 윤석사에게 선택지는 없었습니다
# ㅇㅛㅇ이 산다에 나온 에피소드가 생각나네요
# "해치웠나?"
# "달도 치워야지"
# 나다 싶으면 나인걸 모르셨네... 이젠 아시죠?
# 교수님은 강의하실때 칠판에 빈공간 없다고 나가서 칠판 사오시나요? 아니잖아요
# 아냐는 도대체 어디서 나온 자신감이에요
# 단언컨대 병아리까지 갈려나갈 일이다..!
# 저게 벌써 5년전 영화라고?
# 표정 킹받네
# 모찌모찌...사랑해!!
# ㅋㅋ 헤어지자
# 굿즈로 뿌엉무드등 출시해주세요 뿌엉좌 눈 정가운데에있는 배경화면 출시해주세요
# 저 때 선임들이 그렇게 든든할 수가 없음ㅋㅋㅋㅋㅋㅋㅋ 내 업무가 아니라는 안도감...내 윗선에서 끝나는 평온함...
# '꺾여버린 마음'
# 너무 사랑스러워
# 댓글 38페이지 ================================================================================
#
# 프린터 표정 엉덩국에서 나올거같네 ㅋㅋㅋㅋㅋㅋ
# 으앙 귀여워!!!!!!!@!!!!!¡!!!!!!!!
# 아.. 참고로 전 저 모든걸 저 혼자합니다 ^^ 실험실에 대학원생이 저 하나거든요 ^^ 교수님 잡무을 포함한 실험실의 A to Z 제가 다해요. 저 혼자. 네..
# 앱이 다 찼어 핸드폰 사줘
# ㅋㅋㅋㅋㅋㅋㅋ
# 난 상관 없겠지? = 매우 상관 있을 확률 200%
# 다 뽑아서 알타리김치 해먹고 싶다...
# 이렇게 탄생된 ppt 장인(feat.노예)들...
# 배경 뿌엉 귀여워ㅋㅋ
# 갑자기 난이도 급상승...
# <주말>에 <함께>요? 아득해진다 정말...
# 그냥 교수님을 새로 사면 안되나요?
# 잡'무'라서 무밭이네ㅋㅋㅋㅋㅋ
# 제일 별 거 아닌 일일듯ㅋㅋㅋㅋㅋ 알면서도 가는거죠 뭐ㅠㅠ
# 아... 잡무라서 무밭을 그리신 거였구나ㅋㅋㅋㅋㅋ
# 댓글 39페이지 ================================================================================
#
# 뒤에 일그러진 근똥무 있어요
# 좀 이쁘긴 하군...
# 그래서 잡무가 하트구나 ❣️
# 예전에 인서울 모 대학 교수님의 저널 논문을 번역외주 맡은적이 있는데, 추가로 당연하게 10페이지가량을 더 해달라고 하시기에 이 부분까지 하시면 비용 xx만원 더 청구해야한다고 하니까 그럼 냅두라고, 그부분은 별로 안 중요하니까 연구실에 대학원생들 시키겠다고 해서 경악한 적이 있었지...
# 윤석사네 교수는 보기만 해도 아찔하네...
# ... 학문적 재능에만 모든게 몰리면 안되는 이유
# 저 더듬이 권선징악 해주세요 ㅡㅡ
# 오.....
# 먹어서 없에버리고 싶네 아우...
# 출장 한번 갔다오려면 써야하는 서류는 왤케 많은지...게다가 전문연이라면 서류 2배 이벤트!
# 그림만 보면 참 평화로운디...ㅠ
# 진짜 ㄹㅇ 잡무.. 자기가 운전은 하기 싫은데 맛있는거 먹고싶어서 맨날 애들 운전시켜서 회식하러가던 교수가 생각나는수만...
# 어서와라 석쎄이~~~
# 해맑은 모습만 보여오던 눈사람 퍼지니까 왜 맘이 아프지ㅠㅠ
# 댓글 40페이지 ================================================================================
#
# 사람들이 우리방을 '개족보'라고 부르더라구요  석사고 박사고 졸업을 온 순서로 안 보내고  팀티칭( 교수랑 박사가 팀으로 강의하는거)파트너로 포닥도 아니고 박사 과정을 넣고 등등..그러니 박사고 석사고 진짜 개족보
# 그 와중에 교수 찡찡거림을 잘 들어주면 좀 편해질지 모른다는 (실제예도있고)지푸라기같은 희망으로 개차반 남의 집 아들 대하듯 해주는데...교수님 또 기억력 개똥....
#
# 근데 그그그 그 교수님ㅡㅡ뉴스  전문가의견 같은 인터뷰 자주 나와요ㅋ
# 보면서 생각해요
# 지 방에 사람도 몇명인지 모르고 20대 한테 찡찡거리고 편 안들어주면 삐지는 저 사람이 하는 소리가 뉴스에 나오는 이 세상서는 내가 문제일까, 여기가 문제일까
# 먹고 산책하는게 아니라 악기바리에 등산이라니...
# 저 돈은...다..연구비..학과비.. 등등 개인 사비는 아닙니다...
# ??? : 니가 선택한 대학원생이다, 따라서 이것도 악으로 깡으로 버텨라!!!!
# 와... 학부생입장에서는 볼일 없는 아저씨가 총장인데;;; 으아어어
# 과제에 동원되나
# ㅋㅋㅋ
# 순간 새싹 교수님인줄;;;
# 개귀찮고 개많음...자잘한 일인데 끝이 없어
# 어이쿠 저 새는 해로운 새다ㅋㅋㅋㅋㅋ
# 이건 진짜 상상도 못한 발상이네요ㄷㄷㄷㄷㄷ
# 전 애인이랑 풀코스로 데이트한다 ㄹㅇ 지도교수랑 데이트..? 바로 한강 다이브
# 밝고 환한 미소....확신의 광기상이다
# 이번화는 잡무로 시작해서 잡무로 끝났다
# 그녀는... 플래그를 세워버렸다...
# 댓글 41페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 저건 실적정리일 가능성이 크다고봐요. 매년 교수님들이 여태까지(올해아님)해온 논문, 학회, 과제 등 실적을 모두 정리해서 보고해야하는데 이걸 매년 새롭게 갱신해야하고 교수님의 경력과 연구실의 모든 역사가 총집합된 결정체라 그 분량이 어마무시합니다. 심지어 연도별, 하반기 상반기별로, 학회별로, 모두 순서와 양식에 맞게 정리해야해서 엄청난 잡무지요.. 하나 놓쳐서 빼먹으면 그게 어디사이에 들어가야하는지와 밀리는 번호들때문에 엄청난 스트레스가됩니다..
# 그럼 처음부터 니가 찾으세요
# 없을수가 없죠
# 환경안전원 시찰때가 제일힘든데... 웬만한 잡무보다 힘듬
# 아 미친ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 별로 알고 싶진 않은데...
# 뿌엉이 컷에 나온다는건 어마무시한 일이 나온다는 증거야...
# 눈사람 굿즈 존버합니다~~나와주세요ㅠㅠ
# 조용히만 있으면 절반은 가...
# 원래 순해보이는 얘들이 제일 무서운 법
# 저 부리가 사기템 진짜 귀엽네
# 이때 소진해야하는 남은 연구비도 같이 소비!
# 오우 쒯
# 댓글 42페이지 ================================================================================
#
# 홀리 쉿....저렇게 먹이지나 말던가
# 나는 새삥 모든 게 다 새삥
# 주말에 쉬지도못해 ㅜㅜ
# 100% 상관 있음 없어도 있음 ㅋㅋㅋㅋ
# 불꺼줘
# 광시야각이 아니라시잖아요~
# 저정도 잡무면, 랩실 이동인가? 실험실 세팅 다 바꿔야하는데??? 매번 과제 쓰는 랩실이니 어느정도 면역은 되어있을꺼고?? 아니면 교수님 이사가는데 짐꾼이 필요?
# 이게 가능한건가
# 저 프린터기 표정 아까 어디서 본거같은데
# 보기만 해도 구토 나올것같다
# 너무 귀여워 이게 머슴일이람
# 안가 안가 안가
# 잡무 저 간악한 표정 봐라ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 댓글 43페이지 ================================================================================
#
# 로맨스로 포장한 호러스릴러ㄷㄷ
# 아악 잡무 꺼져 아아악
# 학부생 시험이나 실험수업 조교정도는 되야할거같은데
# 엌ㅋㅋㅋㅋㅋㅋ
# 잡무, 혹은 잡무라고라는 강력한 야근 유발제입니다직장인이나 잘못된 선택을 한 대학원생들이 퇴근하지 못하게 하는 데 사용됩니다
# 야!! 야!! 뒤에!!!
# 교수님의 호감도가 +10 올라갔습니다윤석사님의 호감되가 -10 내려갔습니다
# 모텔.. ?
# 교수님과의 두근두근 데이트❤
# 왜 박사과정의 성격이 그따구로 변하는지 잘 표현해주는 한 화
# 뭔데..  사업 따기 한는건가??
# 거대잡무-->연구실 전인원 총동원ㅋㅋㅋ
# 윤석사님이랑 동기 둘중에 누가 운이 더 없으려나
# 아...  시약확인 PTSD 오지네..
# 시약이 하도 많아서 알파벳 별로, 종류별로 리스트 다 작성하고 시약명-CAS No.- 수량, 용량 확인해서 실험실에만 1500ea정도 확인했던가. 그리고 시약 냉장고는 냄새도 아니지..  지하 하수처리실에는 왜 또 시약창고를 만들어놔갖곤 하수처리장 오수냄새가 향기로울수 있다는걸 처음 깨달음..   거기서도 짜잘한것들로 300병은 있었나?
#
# 그짓을 몇달간격으로 두번인가ㅜ했던걸로 기억함..
# 기계는 손맛이지...
# 댓글 44페이지 ================================================================================
#
# 뭔지 몰라도 제일 최악이겠다
# 악기바리 실시!
# 아예 심부름센터를 차리시죠
# 생각보다 교수님들 간에 부러움과 질투심은 어마어마하더라구요
# 뿌 - 하!
# 그리고 씨를 받아먹고 (강제로)자라야하는 대학원생
# 모니터를 사기 전에는 그런생각이 안드셨나봐요?
# 설마요..
# 오...그래도 나쁘지 않은데ㅋㅋ
# 사망플래그를 미리 세우는걸 보니 다음화도 끔찍하겠군요
# 최소 SPK 출신이실텐데 참. 한심하다는.
# 그럼 본인이 사시지 왜 대학원생을...아니, 이유를 알겠다
# 환장하겠다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 대학원 탈출일지 구독자 밸런스게임 : 전여친/전남친이랑 데이트하기 vs 지도교수님이랑 데이트하기
# 아 됐고 그냥 모니터 하나 사달라고~!(본인이 갖고싶은거임)
# 댓글 45페이지 ================================================================================
#
# 어른을 상대로 때리고싶다는 생각은 들면 안되지만 참 힘들군
# 지도교수님은 C뿌리기보다 더 사악한 잡무뿌리기를 시전하였다!!
# 정말 별거아닌 일이겠네
# 아 가위 주문이었냐고요 ㅋㅋㅋㅋㅋ 반전매력 겁나 귀엽네
# ???:도와줘 도라에몽~~!
# ??:잡일이라고 생각하지 마~배운다고 생각해~
# 프린터기 표정 언짢은거 봐ㅋㅋㅋㅋㅋㅋㅋ
# 대학원에서 거대 잡무라면 어느 정도의 일인가요?
# 마치 사달라고 그리 떼를 써서 사줬더니 막상 잘 안쓰는 애를 보는 듯한 너낌
# 보고서 쓰라고 하면 때릴거야...
# 쎄한 느낌은 대부분 들어맞는 편이라죠
# 잡무도시?
# 이제라도  등산가로 직업을 바꿔보시는건 교수님
# 다 닥쳐 나가...
# 씨가 발아하네요
# 댓글 46페이지 ================================================================================
#
# 초면에 실례지만 누구시죠?
# 로맨틱에서 스릴러로ㅋㅋㅋ
# 산책이라며....
# 영원히 석사과정이면 졸업 안하겠다는 ㄷㄷ
# 저 교수는 지치지도 않네 니가 짱먹어라 라는 말이생각나게함
# 트윈테일 교수님..
# 진격의 잡무
# 아 깜짝야 뿌엉이었어ㅋㅋㅋ
# 그날 대학원생들은 떠올렸다.
# 잡무들이 지배하던 공포를..
#
# 대학원 속에 갇혀 있던 굴욕을...
# 왠지 저  교수님이라면 별이별 요상한 물건들 샀을거같은 느낌
# 학부 교수님 수업 조교도 잡무인가요?
# 하트무? 연애하시나
# 교수 책출판 준비를 왜 작가본인이 안하고 대학원생이? 상상초월데스
# 차라리 등산 시키고 밥 먹이는 게 나았겠다서순 제발
# 제 눈으로 똑똑히 봤구만유
# 댓글 47페이지 ================================================================================
#
# 무치웠나?....
# 잡무 때문에 11시인데 이걸 연구실에서 보고 있는 내가 레전드
# 그럴리가요
# 라는 생각들면 망한겁니다
# 이거 그거잖아 선택지 있는 시뮬레이션게임..▶️ 맛이 좋습니다 하핳하ㅏ하
# 저리 물러가라 이 악마야
# 같은걸로 "싸게" 사줘  불가능한주문을 하시네..
# 식고문이잖아ㅋㅋㅋㅋ
# 잡무의 잡무 나올듯
# 교수님과 주말 데이트....
# 주제 대령이요다
# 뒷모습인데 왜 사악한 미소가 보이는거지 ㄷㄷ...
# 잡무공장이네...
# 눈사람 귀여운데 불쌍해 ㅋㅋ뿌엉은 뿌칼로 훅 그으려나요
# 대한민국 장 건강해지는 그날까지! 위장탈출 넘버원은 계속됩니다! [다음이시간에-]
# 연차보고서 아냐?ㅋㅋㅋㅋㅋㅋㅋ
# 댓글 48페이지 ================================================================================
# 무조건 상관 있음
# 해치웠...
# 여기서 끝이라니. 뭔가 오류겠지
# 눈사람 볼따구 더 빵빵해 진거 같은데ㅋㅋㅋㅋㅋ
# ptsd 온다...
# 뭔가 실화일 듯한...
# 그만해 제발
# 우리 헤어져요
# 잡무가 그 잡'무'였네 ㅋㅋㅋ
# 한땀한땀 장인의 손길로 만든 피피티
# 14년도 군대야?
# 막컷 라떼 뒷모습 심상치 않은데????
# 💔
# 라떼도 피하지 못하는 잡무네..
# 아니ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ교수님도 인간이어따ㅋㅋㅋㅋ
# 댓글 49페이지 ================================================================================
#
# 눈물을 안 흘려ㅋㅋㅋㅋ
# 교수님 자연으로 돌아가세요 그냥
# 인덕션쓰던사람이 불안나온다고 as불럿던거 생각나네
# 와 진짜 보면 볼수록 이 교수는 체력 남다르다..
# 아니 뿌엉 개무서워ㅋㅋㅋㅋㅋㅋㅋㅋ
# 식고문...??
# 아 근데 먹보인 저는 다 시켜보고란 말이 참 로맨틱하네요. ㅎㅎ
# 명*진*사잡무
# 교수님과 데이트vs주말출근흠...주말출근이 나을듯싶다
# 전공서 번역의 질이 안 좋은 경우는, 번역자로 이름 올린 교수 본인이 아닌 그 밑의 대학원생 여럿이 나눠서 한 거일 확률이 매우 높다는 카더라가 갑자기 생각나네요
# 뚱인데요
# 교수님을 새로 사고 싶네요
# Uh?
# 이정도면 교수님 윤석사 졸업하는날 제일 서럽게 우실거같은데
# 오늘도 아방해
# 댓글 50페이지 ================================================================================
#
# Ang?
# 나만 멋있어..?
# 진짜 윤석사네 교수는 진로를 잘못 잡았어
# 대학원 연구하려고 간거 아녔나?
# 굶는 것보다 식고문이 힘들지...
# 왜 분위기가 러블리해지는거죠..
# 무첸도사님...!!
# 확인할 정성으로 찾아 미친
# 쟈기야 왜 칭얼거려
# 김양네 교수님ㅋㅋㅋ
# 전쟁에서 죽는건 항상 젊은이들이지
# 귀엽지 않았다면 텀블러였다
# 기계는 일단 때리면 고쳐짐ㅋㅋ
# 멋있긴하네
# 댓글 51페이지 ================================================================================
#
# 댓글 페이지 개수: 5
#
# 눈사람 녹는다ㅠㅠ
# 전자 기기가 고장 났을 경우
# 일반인 : 일단 쾅쾅쾅 친다.
# 전문가 : 일단 쾅쾅쾅 치고 원인을 찾는다.
# EC 그럼 처음부터 니가 찾아 임마
# 급한일아님
# 등산 엔딩ㅋㅋㅋㅋㅋㅋ
# 좋은데 싫어요....
# 플래그 멈춰!
# 왜 골라도 하필..
# 그럼 총장님이랑 먹으러 올땐 누가 먹어...?
# 교수님 제가 고쳐드릴께요
# 미친ㅋㅋ 호러물인가
# 아냐 그래도 석,박사과정을 버티셨는데 새모니터 사려고 연기하는걸수도 있어
# 뿌엉뿌엉 시뿌엉
# 한달에 한번이겠지만 세상 귀찮음
# 댓글 52페이지 ================================================================================
#
# ㄹㅇ 이런것도 시킨다고????.
# 잡무 레이어드
# ???: 불편하면 자세를 바꿔
# ㅋㅋ그럴리가
# 식고문ㄷㄷ
# 교수님이 윤석사 애정헤서 윤석사만 졸업 빨리 못하는 건 아니죠??
# 어딘가 많이 일그러진 로맨스 남주...
# 와우..
# 눈사람 선배 갔으면 잘 맞았을지도?
# 교수 해병대 출신인가...
# 저 베짱이 언제 나가요..? 계속 있다면 양이 너무 불쌍한데;
# 저걸 다 채울만한 지식과 기록 ㅎㄷㄷㄷ
# 음식 시킬 때 내 모습 같군(욕심 과다)
# 그 발언...
# ???:혼자니?????:어 아직 싱글이야
# 댓글 53페이지 ================================================================================
#
# 견물생심이셨넼ㅋㅋㅋ
# 귀여워.. 꾹 눌러 터뜨리고 싶어..
# 아니 등산 개좋아하네 MT때도 배드민턴에 노래방에 등산에... 산악인이 되어야 했던게 아닐까?
# 그날 요다는 떠올렸다..
# 분석비... 세금계산서... 여비... 식비... 일비... 진짜 산학협력단 사이트 들어갈 때마다 부아가 치밀어오름...
# 데이트 아님?
# 아쎄이... 기열!
# 뿌엉뿌엉뿌엉~
# 보통 이 생각이 들면 걸립니다
# 와.. 진짜 아무것도 없으시구나
# ppt라던가 개인적인 심부름이라던가
# ....교수님 진짜 학문말곤 아무것도....신이 안주셨구나
# 눈사람 귀엽다
# 모니터 큰게 멋있긴 해
# 댓글 54페이지 ================================================================================
#
# 학부생 때는 교수님이랑 개별적으로 만나서 밥사주시는게 좋았는데 그랬는데..
# 초반부터 잡무가 뭔지 궁금했는데 리터럴리 잡무였네요...
# 저 교수는 왜이리 강철체력임?
# 이 교수 귀여운데 뭐지...쎄해...교수여서 그런가
# 정말 급한일(급하지않음.)
# 뿌엉ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# ㅋㅋㅋㅋㅋㅋ 멋있다
# 어우 씨 자동으로 욕나오는 데이트네 여사친도 아니고 교수?
# 누구세요?
# 실화라면 놀라운데?
# ??? 상상초월이다... 앞에서 본건 전부 티끌이었구나
# 교수님.. 정말 실험 빼곤 아무것도 남지 않으셨군요..
# 아 이런 개그 센슼ㅋㅋㅋㅋㅋ
# 별걸 다 시키네 진짜..
# 댓글 55페이지 ================================================================================
#
# 뿌엉 나무에서 지켜보고 있네;
# ㅌㅋㅋㅋㅋㅋㅋ어디서든 감시중이군
# ... 와이게 진짜 실화가
# 공부하러 왔는데 거까지 알아야 되니?
# 아방방.. 아하방방..
# 잡무라고라
# 뽑으면 시끄러운 소리를 낸다
# 잡 "무"ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 쇤네요다
# 맨드레이크 최종 진화 버전
# ㅋㅋㅋㅋㅋ 뭔 연출인가 했네ㅋㅋㅋㅋ
# 공손한 말투와 그렇지 못한 잡무와 얼굴
# 아니 그 무가 이 무였냐구 ㅋㅋㅋㅋㅋㅋ
# 댓글 56페이지 ================================================================================
